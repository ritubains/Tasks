# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
from scipy.spatial.distance import cdist

# %%
from sklearn.datasets.samples_generator import make_blobs
X, y =make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.8, random_state=101)
 


import matplotlib.pyplot as plt

# Plot the training points
plt.scatter(X[:, 0], X[:, 1])
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.show()

# %%
f1 = X[:,0]
f2 = X[:,1]
X = np.array(list(zip(f1, f2)))
plt.scatter(f1, f2, c='black', s=7)

# %%
# Number of clusters
k = 4

C = np.random.randn(4,2)+1.5
print(C)
len(C)
# Out:
# [[0.23665821 1.67574707]
#  [1.63110775 1.81080708]
#  [1.94939686 0.03077347]
#  [0.46528592 0.88034959]]
# 4

# %%
plt.scatter(f1, f2, c='#050505', s=7)
plt.scatter(C_x, C_y, marker='*', s=200, c='g')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2ce692c3da29> in <module>()
#       1 plt.scatter(f1, f2, c='#050505', s=7)
# ----> 2 plt.scatter(C_x, C_y, marker='*', s=200, c='g')
#
# NameError: name 'C_x' is not defined

# %%
def min_index(min_center):
    return np.argmin(min_center)

def mean(point):
    x=point.mean()
    
    return  x

# %%
for i in range(1):
    
#find the euclidean distance between points and centre return the array of euclidean distance
    min_centerlist=cdist(X,C,'euclidean')
#broadcast the min function on  every element of array to find the min distance from array
#min_dist_ind=lambda t: np.argmin(t)

#prediction=np.array([min_dist_ind(dist)for dist in min_centerlist])
#predictions

    prediction=np.apply_along_axis(min_index,axis=1,arr=min_centerlist)
    
        #df = pd.DataFrame({'pred0':prediction[:,0],'pred1':prediction[:,1],'pred2':prediction[:,2],'pred3':prediction[:,2]})
    new_center=np.zeros(8).reshape(4,2)
    i=0
    for center in C:
        new_center[i]=np.apply_along_axis(mean,0,X[prediction==i])
        i=i+1
    #new_center=pd.get_dummies(df,prefix='pred')
    #new_center1=np.array(new_center)
    #c=np.transpose(new_center1)
    #prod=np.dot(c,X)

# %%
prediction
# Out:
# array([0, 1, 0, 1, 1, 3, 1, 0, 1, 0, 0, 0, 1, 1, 0, 3, 1, 0, 3, 0, 3, 3,
#        1, 3, 0, 3, 3, 2, 1, 1, 0, 3, 1, 2, 0, 0, 3, 3, 3, 1, 3, 0, 0, 0,
#        0, 1, 0, 1, 3, 0, 2, 0, 1, 3, 3, 0, 1, 1, 0, 1, 3, 1, 3, 0, 1, 3,
#        3, 1, 1, 3, 1, 1, 3, 0, 3, 1, 1, 0, 0, 0, 0, 3, 1, 3, 3, 3, 3, 0,
#        1, 3, 3, 3, 3, 0, 0, 3, 1, 0, 3, 1, 0, 3, 1, 3, 0, 0, 3, 1, 3, 3,
#        1, 0, 0, 1, 3, 1, 0, 0, 1, 0, 1, 0, 0, 0, 0, 1, 0, 3, 3, 0, 0, 0,
#        0, 3, 3, 0, 1, 0, 1, 2, 3, 1, 3, 0, 0, 1, 0, 3, 0, 0, 0, 0, 0, 1,
#        2, 0, 1, 1, 1, 2, 1, 1, 0, 0, 3, 0, 0, 1, 0, 2, 1, 1, 0, 0, 0, 0,
#        1, 1, 3, 1, 0, 3, 3, 0, 3, 3, 3, 3, 3, 3, 3, 1, 1, 0, 3, 1, 1, 1,
#        3, 1], dtype=int64)

# %%
fig,(ax1,ax2)=plt.subplots(1,2,sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(X[:,0],X[:,1],c=prediction,cmap='rainbow')
ax1.scatter(new_center[:][0],new_center[:][1],marker="*")


ax2.set_title('Original')
ax2.scatter(X[:,0],X[:,1],c=y,cmap='rainbow')

# %%
for i in range(5):
    
    min_centerlist=cdist(X,new_center,'euclidean')
    prediction=np.apply_along_axis(min_index,axis=1,arr=min_centerlist)
    i=0
    
    new_center=np.zeros(8).reshape(4,2)
    i=0
    for center in C:
        new_center[i]=np.apply_along_axis(mean,0,X[prediction==i])
        
        i=i+1
    i=i+1

# %% [markdown]
# min_centerlist

# %%
fig,(ax1,ax2)=plt.subplots(1,2,sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(X[:,0],X[:,1],c=prediction,cmap='rainbow')
ax1.scatter(new_center[:,0],new_center[:,1],marker='+',s=180)

ax2.set_title('Original')
ax2.scatter(X[:,0],X[:,1],c=y,cmap='rainbow')
