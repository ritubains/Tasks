# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
t0=20
x=np.random.random(30)*10
x=t1-x
t1=20
y=np.random.random(30)*15
y=t1-y

# %%
t2=80
x1=np.random.random(20)*20
x1=t2-x1
t3=80
y1=np.random.random(20)*30
y1=t3-y1


t4=60
x2=np.random.random(35)*35
x2=t4-x2
y2=np.random.random(35)*40
t5=60
y2=t5-y2

# %%
plt.scatter(x,y)
plt.scatter(x1,y1)
plt.scatter(x2,y2)

# %%
beta1=[10,20]
beta2=[2,3]
beta3=[14,21]

# %%
plt.scatter(x,y)
plt.scatter(x1,y1)
plt.scatter(x2,y2)
plt.scatter(beta1[0],beta1[1],linewidths=10)
plt.scatter(beta2[0],beta2[1],linewidths=10)
plt.scatter(beta3[0],beta3[1],linewidths=10)

# %%
from sklearn.datasets.samples_generator import make_blobs
centers = np.array([[2, 2], [8, 9], [9, 5], [3,9]])
X, y =make_blobs(n_samples=300, n_features=2, centers=centers, cluster_std=0.5, center_box=(1, 10.0), shuffle=True, random_state=0)
 


import matplotlib.pyplot as plt

# Plot the training points
plt.scatter(X[:, 0], X[:, 1])
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.show()

# %%
f1 = X[:,0]
f2 = X[:,1]
X = np.array(list(zip(f1, f2)))
plt.scatter(f1, f2, c='black', s=7)

# %%
#Euclidean Distance Caculator
def dist(a, b, ax=1):
    return np.linalg.norm(a - b, axis=ax)

# %%
# Number of clusters
k = 4
# X coordinates of random centroids
C_x = np.random.randint(0, np.max(X)-7, size=k)
# Y coordinates of random centroids
C_y = np.random.randint(0, np.max(X)-7, size=k)
C = np.array(list(zip(C_x, C_y)), dtype=np.float32)
print(C)
# Out:
# [[2. 2.]
#  [0. 1.]
#  [1. 2.]
#  [1. 2.]]

# %%
plt.scatter(f1, f2, c='#050505', s=7)
plt.scatter(C_x, C_y, marker='*', s=200, c='g')

# %%
predictions=np.zeros(len(X))

# %%
for point in X:
    min_centerlist=[]
    for center in C:
        euc_dist=((point[0]-center[0])**2+(point[1]-center[1])**2)
        min_centerlist.append(euc_dist)
    index=np.argmin(min_centerlist)
    predictions[i]=index

# %%
dist(X[0],C)

# %% [markdown]
# k mean using sk learn

# %%
import matplotlib.pyplot as plt  
# %matplotlib inline
import numpy as np  
from sklearn.cluster import KMeans

# %%
from sklearn.datasets.samples_generator import make_blobs
centers = [[2, 2], [8, 9], [9, 5], [3,9]]
X, y =make_blobs(n_samples=300, n_features=2, centers=centers, cluster_std=0.5, center_box=(1, 10.0), shuffle=True, random_state=0)
 


import matplotlib.pyplot as plt

# Plot the training points
plt.scatter(X[:, 0], X[:, 1])
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.show()

# %%
from sklearn.cluster import KMeans 
from scipy.spatial.distance import cdist

kmeans = KMeans(n_clusters=4)  
kmeans.fit(X,y)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
z=kmeans.labels_

# %%
print(kmeans.cluster_centers_)
# Out:
# [[7.95481443 8.9748611 ]
#  [2.91777511 8.94861912]
#  [2.0135227  2.11186092]
#  [8.94295873 4.91578577]]

# %%
fig,(ax1,ax2)=plt.subplots(1,2,sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(X[:,0],X[:,1],c=z,cmap='rainbow')

ax2.set_title('Original')
ax2.scatter(X[:,0],X[:,1],c=y,cmap='rainbow')

# %%
distortion=[]
k1=range(1,10)
for k in k1:
    kmeans = KMeans(n_clusters=k)  
    kmeans.fit(X) 
    distortion.append(sum(np.min(cdist(X,kmeans.cluster_centers_),axis=1))/X.shape[0])
    print(np.min(cdist(X,kmeans.cluster_centers_))

# %%
plt.plot(k1,distortion,'bx-')
plt.show()

# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
# Importing the dataset
data = pd.read_csv('xclara.csv')
print(data.shape)
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-dfc9db3f3e83> in <module>()
#       1 # Importing the dataset
# ----> 2 data = pd.read_csv('xclara.csv')
#       3 print(data.shape)
#       4 data.head()
#
# ...

# %%
# Getting the values and plotting it
f1 = data['V1'].values
f2 = data['V2'].values
X = np.array(list(zip(f1, f2)))
plt.scatter(f1, f2, c='black', s=7)

# %%
#Euclidean Distance Caculator
def dist(a, b, ax=1):
    return np.linalg.norm(a - b, axis=ax)

# %%
# Number of clusters
k = 3
# X coordinates of random centroids
C_x = np.random.randint(0, np.max(X)-20, size=k)
# Y coordinates of random centroids
C_y = np.random.randint(0, np.max(X)-20, size=k)
C = np.array(list(zip(C_x, C_y)), dtype=np.float32)
print(C)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-028ba95ce228> in <module>()
#       2 k = 3
#       3 # X coordinates of random centroids
# ----> 4 C_x = np.random.randint(0, np.max(X)-20, size=k)
#       5 # Y coordinates of random centroids
#       6 C_y = np.random.randint(0, np.max(X)-20, size=k)
#
# mtrand.pyx in mtrand.RandomState.randint()
#
# ValueError: low >= high

# %%
# Plotting along with the Centroids
plt.scatter(f1, f2, c='#050505', s=7)
plt.scatter(C_x, C_y, marker='*', s=200, c='g')

# %%
# To store the value of centroids when it updates
C_old = np.zeros(C.shape)
# Cluster Lables(0, 1, 2)
clusters = np.zeros(len(X))
# Error func. - Distance between new centroids and old centroids
error = dist(C, C_old, None)
# Loop will run till the error becomes zero
while error != 0:
    # Assigning each value to its closest cluster
    for i in range(len(X)):
        distances = dist(X[i], C)
        cluster = np.argmin(distances)
        clusters[i] = cluster
    # Storing the old centroid values
    C_old = deepcopy(C)
    # Finding the new centroids by taking the average value
    for i in range(k):
        points = [X[j] for j in range(len(X)) if clusters[j] == i]
        C[i] = np.mean(points, axis=0)
    error = dist(C, C_old, None)
colors = ['r', 'g', 'b', 'y', 'c', 'm']
fig, ax = plt.subplots()
for i in range(k):
        points = np.array([X[j] for j in range(len(X)) if clusters[j] == i])
        ax.scatter(points[:, 0], points[:, 1], s=7, c=colors[i])
ax.scatter(C[:, 0], C[:, 1], marker='*', s=200, c='#050505')
